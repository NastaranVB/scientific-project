# %%
import scientific_project

# %%
import scientific_project.datahelper as dh

# %%
data = dh.open_data("data/patients.csv")

# %%
import seaborn as sns
sns.barplot(data=data, y="weight", hue="active")
# Out:
# <Axes: ylabel='weight'>
